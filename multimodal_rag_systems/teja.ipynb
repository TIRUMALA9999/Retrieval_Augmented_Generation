# %%
import os
os.environ["OLLAMA_HOST"] = "http://localhost:11434"
import ollama

# %%
# save as test_connect.py and run with the same python you will run your script
import requests
try:
    r = requests.get("http://localhost:11434/", timeout=5)
    print("HTTP status:", r.status_code)
    print("Body:", r.text)
except Exception as e:
    print("Connection failed:", type(e).__name__, e)
# Out:
# HTTP status: 200
# Body: Ollama is running

# %%
import ollama
from IPython.display import Markdown, display

resp = ollama.chat(
    model="llama3.2:latest",
    messages=[
        {
            "role": "user",
            "content": "machine learning",
            #"images": [r"D:\Courses_1\llms_course\rag\multimodal_rag_systems\dogs.png"]   # <-- Images go inside the message
        }
    ]
)

display(Markdown(resp['message']['content']))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import ollama
#       2 from IPython.display import Markdown, display
# ----> 4 resp = ollama.chat(
#       5     model="llama3.2:latest",
#       6     messages=[
#       7         {
#       8             "role": "user",
#       9             "content": "machine learning",
#      10             #"images": [r"D:\Courses_1\llms_course\rag\multimodal_rag_systems\dogs.png"]   # <-- Images go inside the message
#      11         }
#      12     ]
#      13 )
#      15 display(Markdown(resp['message']['content']))
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\ollama\_client.py:351, in Client.chat(self, model, messages, tools, stream, think, format, options, keep_alive)
#     306 def chat(
#     307   self,
#     308   model: str = '',
#    (...)
# ...

# %%
import ollama
from IPython.display import Markdown, display

resp = ollama.chat(
    model="llama3.2-vision",
    messages=[{"role":"user", "content":"Describe this image."}],
    images=["dogs.png"]
)

display(Markdown(resp["message"]["content"]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 import ollama
#       2 from IPython.display import Markdown, display
# ----> 4 resp = ollama.chat(
#       5     model="llama3.2-vision",
#       6     messages=[{"role":"user", "content":"Describe this image."}],
#       7     images=["dogs.png"]
#       8 )
#      10 display(Markdown(resp["message"]["content"]))
#
# TypeError: Client.chat() got an unexpected keyword argument 'images'

# %%
# save as test_ollama_image.py


#image_path = r"D:\Courses_1\llms_course\rag\multimodal_rag_systems\dogs.png"   # change to the actual absolute path
resp = ollama.chat(
    model="llama3.2-vision:latest",
    messages=[
        {
            "role":"user",
            "content":"Describe this image.",
            'images':['dogs.png']
        }
    ]
    
)
print(resp)

# %%
import os
os.getcwd()
# Out:
# 'd:\\Courses_1\\llms_course\\rag\\multimodal_rag_systems'

# %%
import os, traceback
import ollama
from IPython.display import Markdown, display

# Configure host if you set it earlier
# os.environ["OLLAMA_HOST"] = "http://localhost:11434"

# Put your image path here (use absolute path)
image_path = r"D:\Courses_1\llms_course\rag\multimodal_rag_systems\dogs.png"

print("Python executable:", os.sys.executable)
print("Current working dir:", os.getcwd())
print("Image path:", image_path)
print("Exists:", os.path.exists(image_path))
print("File size (bytes):", os.path.getsize(image_path) if os.path.exists(image_path) else "n/a")
print()
# Out:
# Python executable: c:\Users\Lenovo\anaconda3\python.exe
# Current working dir: d:\Courses_1\llms_course\rag\multimodal_rag_systems
# Image path: D:\Courses_1\llms_course\rag\multimodal_rag_systems\dogs.png
# Exists: True
# File size (bytes): 375855

# %%
import ollama

response = ollama.chat(
    model='llama3.2-vision:latest',
    messages=[{
        'role': 'user',
        'content': 'Describe this image.',
        'images': ['dogs.png']
    }]
)

display(Markdown(response.message.content))
