# %%
pip install llama-index qdrant_client torch transformers
# Out:
# Requirement already satisfied: llama-index in c:\users\lenovo\anaconda3\lib\site-packages (0.14.8)
# Requirement already satisfied: qdrant_client in c:\users\lenovo\anaconda3\lib\site-packages (1.15.1)
# Requirement already satisfied: torch in c:\users\lenovo\anaconda3\lib\site-packages (2.9.0)
# Requirement already satisfied: transformers in c:\users\lenovo\anaconda3\lib\site-packages (4.57.1)
# Requirement already satisfied: llama-index-cli<0.6,>=0.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index) (0.5.3)
# Requirement already satisfied: llama-index-core<0.15.0,>=0.14.8 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index) (0.14.8)
# Requirement already satisfied: llama-index-embeddings-openai<0.6,>=0.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index) (0.5.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index) (0.9.4)
# Requirement already satisfied: llama-index-llms-openai<0.7,>=0.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index) (0.6.8)
# Requirement already satisfied: llama-index-readers-file<0.6,>=0.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index) (0.5.4)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index) (0.5.1)
# Requirement already satisfied: nltk>3.8.1 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index) (3.9.1)
# Requirement already satisfied: grpcio>=1.41.0 in c:\users\lenovo\anaconda3\lib\site-packages (from qdrant_client) (1.76.0)
# Requirement already satisfied: httpx>=0.20.0 in c:\users\lenovo\anaconda3\lib\site-packages (from httpx[http2]>=0.20.0->qdrant_client) (0.27.0)
# Requirement already satisfied: numpy>=1.26 in c:\users\lenovo\anaconda3\lib\site-packages (from qdrant_client) (1.26.4)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in c:\users\lenovo\anaconda3\lib\site-packages (from qdrant_client) (3.2.0)
# Requirement already satisfied: protobuf>=3.20.0 in c:\users\lenovo\anaconda3\lib\site-packages (from qdrant_client) (4.25.3)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8 in c:\users\lenovo\anaconda3\lib\site-packages (from qdrant_client) (2.12.4)
# Requirement already satisfied: urllib3<3,>=1.26.14 in c:\users\lenovo\anaconda3\lib\site-packages (from qdrant_client) (2.2.3)
# Requirement already satisfied: filelock in c:\users\lenovo\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\lenovo\anaconda3\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\lenovo\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\lenovo\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\lenovo\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\lenovo\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\lenovo\anaconda3\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (0.36.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: anyio in c:\users\lenovo\anaconda3\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant_client) (4.2.0)
# Requirement already satisfied: certifi in c:\users\lenovo\anaconda3\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant_client) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\lenovo\anaconda3\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant_client) (1.0.2)
# Requirement already satisfied: idna in c:\users\lenovo\anaconda3\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant_client) (3.7)
# Requirement already satisfied: sniffio in c:\users\lenovo\anaconda3\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant_client) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\lenovo\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant_client) (0.14.0)
# Requirement already satisfied: h2<5,>=3 in c:\users\lenovo\anaconda3\lib\site-packages (from httpx[http2]>=0.20.0->qdrant_client) (4.3.0)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (3.10.5)
# Requirement already satisfied: aiosqlite in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (0.21.0)
# Requirement already satisfied: banks<3,>=2.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (2.2.0)
# Requirement already satisfied: dataclasses-json in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (1.2.0)
# Requirement already satisfied: llama-index-workflows!=2.9.0,<3,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (2.11.1)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (1.6.0)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (10.4.0)
# Requirement already satisfied: platformdirs in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (4.5.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in c:\users\lenovo\anaconda3\lib\site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15.0,>=0.14.8->llama-index) (2.0.34)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (8.5.0)
# Requirement already satisfied: tiktoken>=0.7.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (0.12.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15.0,>=0.14.8->llama-index) (1.14.1)
# Requirement already satisfied: openai>=1.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (2.7.2)
# Requirement already satisfied: llama-cloud==0.1.35 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (0.1.35)
# Requirement already satisfied: beautifulsoup4<5,>=4.12.3 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (4.12.3)
# Requirement already satisfied: defusedxml>=0.7.1 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (0.7.1)
# Requirement already satisfied: pandas<2.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (2.2.2)
# Requirement already satisfied: pypdf<7,>=5.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (6.2.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.54)
# Requirement already satisfied: click in c:\users\lenovo\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in c:\users\lenovo\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: pywin32>=226 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from portalocker<4.0,>=2.7.0->qdrant_client) (308)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant_client) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant_client) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant_client) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.8->llama-index) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.8->llama-index) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.8->llama-index) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.8->llama-index) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.8->llama-index) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.8->llama-index) (1.11.0)
# Requirement already satisfied: griffe in c:\users\lenovo\anaconda3\lib\site-packages (from banks<3,>=2.2.0->llama-index-core<0.15.0,>=0.14.8->llama-index) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\lenovo\anaconda3\lib\site-packages (from beautifulsoup4<5,>=4.12.3->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2.5)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\users\lenovo\anaconda3\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant_client) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in c:\users\lenovo\anaconda3\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant_client) (4.1.0)
# Requirement already satisfied: llama-index-instrumentation>=0.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-workflows!=2.9.0,<3,>=2->llama-index-core<0.15.0,>=0.14.8->llama-index) (0.4.2)
# Requirement already satisfied: llama-cloud-services>=0.6.54 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.54)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (0.12.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from pandas<2.3.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas<2.3.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas<2.3.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2023.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15.0,>=0.14.8->llama-index) (3.0.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.15.0,>=0.14.8->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\lenovo\anaconda3\lib\site-packages (from dataclasses-json->llama-index-core<0.15.0,>=0.14.8->llama-index) (3.26.1)
# Requirement already satisfied: python-dotenv<2,>=1.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-cloud-services>=0.6.54->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (1.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas<2.3.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nest_asyncio
import qdrant_client

from llama_index.core import Settings
from llama_index.core import PromptTemplate
from llama_index.llms.ollama import Ollama
from llama_index.core import StorageContext
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core.postprocessor import SentenceTransformerRerank
#from llama_index.embeddings.fastembed import FastEmbedEmbedding
from llama_index.vector_stores.qdrant import QdrantVectorStore

from IPython.display import Markdown, display

# %%
pip install llama-index-embeddings-fastembed
# Out:
# Collecting llama-index-embeddings-fastembedNote: you may need to restart the kernel to use updated packages.
#
#   Downloading llama_index_embeddings_fastembed-0.5.0-py3-none-any.whl.metadata (381 bytes)
# Requirement already satisfied: llama-index-core<0.15,>=0.13.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-embeddings-fastembed) (0.14.8)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (3.10.5)
# Requirement already satisfied: aiosqlite in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (0.21.0)
# Requirement already satisfied: banks<3,>=2.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (2.2.0)
# Requirement already satisfied: dataclasses-json in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (2024.6.1)
# Requirement already satisfied: httpx in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (0.27.0)
# Requirement already satisfied: llama-index-workflows!=2.9.0,<3,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (2.11.1)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (3.3)
# Requirement already satisfied: nltk>3.8.1 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (3.9.1)
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (10.4.0)
# Requirement already satisfied: platformdirs in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (4.5.0)
# Requirement already satisfied: pydantic>=2.8.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (2.12.4)
# Requirement already satisfied: pyyaml>=6.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (6.0.1)
# Requirement already satisfied: requests>=2.31.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (2.32.3)
# Requirement already satisfied: setuptools>=80.9.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (80.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in c:\users\lenovo\anaconda3\lib\site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (2.0.34)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (8.5.0)
# Requirement already satisfied: tiktoken>=0.7.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (0.12.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (4.15.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (1.14.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (1.11.0)
# Requirement already satisfied: griffe in c:\users\lenovo\anaconda3\lib\site-packages (from banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (1.15.0)
# Requirement already satisfied: jinja2 in c:\users\lenovo\anaconda3\lib\site-packages (from banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (3.1.4)
# Requirement already satisfied: llama-index-instrumentation>=0.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from llama-index-workflows!=2.9.0,<3,>=2->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (0.4.2)
# Requirement already satisfied: click in c:\users\lenovo\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (8.1.7)
# Requirement already satisfied: joblib in c:\users\lenovo\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\lenovo\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (3.0.1)
# Requirement already satisfied: colorama in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from tqdm<5,>=4.66.1->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\lenovo\anaconda3\lib\site-packages (from dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (3.26.1)
# Requirement already satisfied: anyio in c:\users\lenovo\anaconda3\lib\site-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\lenovo\anaconda3\lib\site-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\lenovo\anaconda3\lib\site-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\lenovo\anaconda3\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (24.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from jinja2->banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-fastembed) (2.1.3)
# Downloading llama_index_embeddings_fastembed-0.5.0-py3-none-any.whl (3.8 kB)
# Installing collected packages: llama-index-embeddings-fastembed
# Successfully installed llama-index-embeddings-fastembed-0.5.0

# %%
pip install fastembed
# Out:
# Collecting fastembedNote: you may need to restart the kernel to use updated packages.
#
#   Downloading fastembed-0.7.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: huggingface-hub<1.0,>=0.20 in c:\users\lenovo\anaconda3\lib\site-packages (from fastembed) (0.36.0)
# Collecting loguru<0.8.0,>=0.7.2 (from fastembed)
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Collecting mmh3<6.0.0,>=4.1.0 (from fastembed)
#   Downloading mmh3-5.2.0-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.26 in c:\users\lenovo\anaconda3\lib\site-packages (from fastembed) (1.26.4)
# Collecting onnxruntime!=1.20.0,>=1.17.0 (from fastembed)
#   Downloading onnxruntime-1.23.2-cp312-cp312-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: pillow<12.0.0,>=10.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from fastembed) (10.4.0)
# Collecting py-rust-stemmers<0.2.0,>=0.1.0 (from fastembed)
#   Downloading py_rust_stemmers-0.1.5-cp312-none-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: requests<3.0,>=2.31 in c:\users\lenovo\anaconda3\lib\site-packages (from fastembed) (2.32.3)
# Requirement already satisfied: tokenizers<1.0,>=0.15 in c:\users\lenovo\anaconda3\lib\site-packages (from fastembed) (0.22.1)
# Requirement already satisfied: tqdm<5.0,>=4.66 in c:\users\lenovo\anaconda3\lib\site-packages (from fastembed) (4.66.5)
# Requirement already satisfied: filelock in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.20->fastembed) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.20->fastembed) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from huggingface-hub<1.0,>=0.20->fastembed) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.20->fastembed) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.20->fastembed) (4.15.0)
# Requirement already satisfied: colorama>=0.3.4 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from loguru<0.8.0,>=0.7.2->fastembed) (0.4.6)
# Collecting win32-setctime>=1.0.0 (from loguru<0.8.0,>=0.7.2->fastembed)
#   Downloading win32_setctime-1.2.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting coloredlogs (from onnxruntime!=1.20.0,>=1.17.0->fastembed)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime!=1.20.0,>=1.17.0->fastembed)
#   Downloading flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: protobuf in c:\users\lenovo\anaconda3\lib\site-packages (from onnxruntime!=1.20.0,>=1.17.0->fastembed) (4.25.3)
# Requirement already satisfied: sympy in c:\users\lenovo\anaconda3\lib\site-packages (from onnxruntime!=1.20.0,>=1.17.0->fastembed) (1.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3.0,>=2.31->fastembed) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3.0,>=2.31->fastembed) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3.0,>=2.31->fastembed) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3.0,>=2.31->fastembed) (2024.8.30)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime!=1.20.0,>=1.17.0->fastembed)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from sympy->onnxruntime!=1.20.0,>=1.17.0->fastembed) (1.3.0)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime!=1.20.0,>=1.17.0->fastembed)
#   Downloading pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Downloading fastembed-0.7.3-py3-none-any.whl (105 kB)
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
# Downloading mmh3-5.2.0-cp312-cp312-win_amd64.whl (41 kB)
# Downloading onnxruntime-1.23.2-cp312-cp312-win_amd64.whl (13.5 MB)
#    ---------------------------------------- 0.0/13.5 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/13.5 MB 5.6 MB/s eta 0:00:03
#    ------- -------------------------------- 2.4/13.5 MB 5.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.7/13.5 MB 5.9 MB/s eta 0:00:02
#    -------------- ------------------------- 4.7/13.5 MB 5.8 MB/s eta 0:00:02
#    ------------------ --------------------- 6.3/13.5 MB 5.9 MB/s eta 0:00:02
#    --------------------- ------------------ 7.3/13.5 MB 6.0 MB/s eta 0:00:02
#    ------------------------- -------------- 8.7/13.5 MB 5.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.4/13.5 MB 5.7 MB/s eta 0:00:01
#    ------------------------------- -------- 10.7/13.5 MB 5.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 12.1/13.5 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  13.4/13.5 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 13.5/13.5 MB 5.6 MB/s eta 0:00:00
# Downloading py_rust_stemmers-0.1.5-cp312-none-win_amd64.whl (209 kB)
# Downloading win32_setctime-1.2.0-py3-none-any.whl (4.1 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Installing collected packages: py-rust-stemmers, flatbuffers, win32-setctime, pyreadline3, mmh3, loguru, humanfriendly, coloredlogs, onnxruntime, fastembed
# Successfully installed coloredlogs-15.0.1 fastembed-0.7.3 flatbuffers-25.9.23 humanfriendly-10.0 loguru-0.7.3 mmh3-5.2.0 onnxruntime-1.23.2 py-rust-stemmers-0.1.5 pyreadline3-3.5.4 win32-setctime-1.2.0

# %%
from llama_index.embeddings.fastembed import FastEmbedEmbedding

# %%
import nest_asyncio

nest_asyncio.apply()

# %%
llm = Ollama(model="llama3.2:1b", request_timeout=120.0)

embed_model = FastEmbedEmbedding(model_name="BAAI/bge-large-en-v1.5")

rerank = SentenceTransformerRerank(model="BAAI/bge-reranker-base", top_n=2)
# Out:
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/742 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# C:\Users\Lenovo\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Lenovo\AppData\Local\Temp\fastembed_cache\models--qdrant--bge-large-en-v1.5-onnx. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.onnx:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# 2025-11-11 18:01:36.893 | ERROR    | fastembed.common.model_management:download_model:430 - Could not download model from HuggingFace: [WinError 1314] A required privilege is not held by the client: '..\\..\\blobs\\9bbecc17cabbcbd3112c14d6982b51403b264bfa' -> 'C:\\Users\\Lenovo\\AppData\\Local\\Temp\\fastembed_cache\\models--qdrant--bge-large-en-v1.5-onnx\\snapshots\\dc76b2c078fc38f0d243233d0ab0b51de925557e\\special_tokens_map.json' Falling back to other sources.
# 2025-11-11 18:01:36.895 | ERROR    | fastembed.common.model_management:download_model:452 - Could not download model from either source, sleeping for 3.0 seconds, 2 retries left.
# 2025-11-11 18:02:10.059 | ERROR    | fastembed.common.model_management:download_model:430 - Could not download model from HuggingFace: (ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')), '(Request ID: 7d0cb6b9-88e2-45c3-984a-38556b481ce7)') Falling back to other sources.
# 2025-11-11 18:02:10.062 | ERROR    | fastembed.common.model_management:download_model:452 - Could not download model from either source, sleeping for 9.0 seconds, 1 retries left.
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/799 [00:00<?, ?B/s]
# C:\Users\Lenovo\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Lenovo\.cache\huggingface\hub\models--BAAI--bge-reranker-base. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 5
#       1 llm = Ollama(model="llama3.2:1b", request_timeout=120.0)
#       3 embed_model = FastEmbedEmbedding(model_name="BAAI/bge-large-en-v1.5")
# ----> 5 rerank = SentenceTransformerRerank(model="BAAI/bge-reranker-base", top_n=2)
#
# File ~\anaconda3\Lib\site-packages\llama_index\core\postprocessor\sbert_rerank.py:51, in SentenceTransformerRerank.__init__(self, top_n, model, device, keep_retrieval_score, trust_remote_code)
#      44 device = infer_torch_device() if device is None else device
#      45 super().__init__(
#      46     top_n=top_n,
#      47     model=model,
#      48     device=device,
#      49     keep_retrieval_score=keep_retrieval_score,
#      50 )
# ---> 51 self._model = CrossEncoder(
#      52     model,
#      53     max_length=DEFAULT_SENTENCE_TRANSFORMER_MAX_LENGTH,
#      54     device=device,
#      55     trust_remote_code=trust_remote_code,
#      56 )
#
# File ~\anaconda3\Lib\site-packages\sentence_transformers\cross_encoder\util.py:39, in cross_encoder_init_args_decorator.<locals>.wrapper(self, *args, **kwargs)
#      36     else:
#      37         kwargs["config_kwargs"]["classifier_dropout"] = classifier_dropout
# ---> 39 return func(self, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:176, in CrossEncoder.__init__(self, model_name_or_path, num_labels, max_length, activation_fn, device, cache_folder, trust_remote_code, revision, local_files_only, token, model_kwargs, tokenizer_kwargs, config_kwargs, model_card_data, backend)
#     174 if num_labels is not None:
#     175     config.num_labels = num_labels
# --> 176 self._load_model(
#     177     model_name_or_path,
#     178     config=config,
#     179     backend=backend,
#     180     cache_dir=cache_folder,
#     181     trust_remote_code=trust_remote_code,
#     182     revision=revision,
#     183     local_files_only=local_files_only,
#     184     token=token,
#     185     **model_kwargs,
#     186 )
#     188 if "model_max_length" not in tokenizer_kwargs and max_length is not None:
#     189     tokenizer_kwargs["model_max_length"] = max_length
#
# File ~\anaconda3\Lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:237, in CrossEncoder._load_model(self, model_name_or_path, config, backend, **model_kwargs)
#     229 def _load_model(
#     230     self,
#     231     model_name_or_path: str,
#    (...)
#     234     **model_kwargs,
#     235 ) -> None:
#     236     if backend == "torch":
# --> 237         self.model: PreTrainedModel = AutoModelForSequenceClassification.from_pretrained(
#     238             model_name_or_path,
#     239             config=config,
#     240             **model_kwargs,
#     241         )
#     242     elif backend == "onnx":
#     243         self.model = load_onnx_model(
#     244             model_name_or_path=model_name_or_path,
#     245             config=config,
#     246             task_name="sequence-classification",
#     247             **model_kwargs,
#     248         )
#
# File ~\anaconda3\Lib\site-packages\transformers\models\auto\auto_factory.py:604, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     602     if model_class.config_class == config.sub_configs.get("text_config", None):
#     603         config = config.get_text_config()
# --> 604     return model_class.from_pretrained(
#     605         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     606     )
#     607 raise ValueError(
#     608     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     609     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping)}."
#     610 )
#
# File ~\anaconda3\Lib\site-packages\transformers\modeling_utils.py:277, in restore_default_dtype.<locals>._wrapper(*args, **kwargs)
#     275 old_dtype = torch.get_default_dtype()
#     276 try:
# --> 277     return func(*args, **kwargs)
#     278 finally:
#     279     torch.set_default_dtype(old_dtype)
#
# File ~\anaconda3\Lib\site-packages\transformers\modeling_utils.py:4900, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4890 if (
#    4891     gguf_file
#    4892     and device_map is not None
#    4893     and ((isinstance(device_map, dict) and "disk" in device_map.values()) or "disk" in device_map)
#    4894 ):
#    4895     raise RuntimeError(
#    4896         "One or more modules is configured to be mapped to disk. Disk offload is not supported for models "
#    4897         "loaded from GGUF files."
#    4898     )
# -> 4900 checkpoint_files, sharded_metadata = _get_resolved_checkpoint_files(
#    4901     pretrained_model_name_or_path=pretrained_model_name_or_path,
#    4902     subfolder=subfolder,
#    4903     variant=variant,
#    4904     gguf_file=gguf_file,
#    4905     from_tf=from_tf,
#    4906     from_flax=from_flax,
#    4907     use_safetensors=use_safetensors,
#    4908     cache_dir=cache_dir,
#    4909     force_download=force_download,
#    4910     proxies=proxies,
#    4911     local_files_only=local_files_only,
#    4912     token=token,
#    4913     user_agent=user_agent,
#    4914     revision=revision,
#    4915     commit_hash=commit_hash,
#    4916     is_remote_code=cls._auto_class is not None,
#    4917     transformers_explicit_filename=transformers_explicit_filename,
#    4918 )
#    4920 is_sharded = sharded_metadata is not None
#    4921 is_quantized = hf_quantizer is not None
#
# File ~\anaconda3\Lib\site-packages\transformers\modeling_utils.py:1037, in _get_resolved_checkpoint_files(pretrained_model_name_or_path, subfolder, variant, gguf_file, from_tf, from_flax, use_safetensors, cache_dir, force_download, proxies, local_files_only, token, user_agent, revision, commit_hash, is_remote_code, transformers_explicit_filename)
#    1022 try:
#    1023     # Load from URL or cache if already cached
#    1024     cached_file_kwargs = {
#    1025         "cache_dir": cache_dir,
#    1026         "force_download": force_download,
#    (...)
#    1035         "_commit_hash": commit_hash,
#    1036     }
# -> 1037     resolved_archive_file = cached_file(pretrained_model_name_or_path, filename, **cached_file_kwargs)
#    1039     # Since we set _raise_exceptions_for_missing_entries=False, we don't get an exception but a None
#    1040     # result when internet is up, the repo and revision exist, but the file does not.
#    1041     if resolved_archive_file is None and filename == _add_variant(SAFE_WEIGHTS_NAME, variant):
#    1042         # Maybe the checkpoint is sharded, we try to grab the index name in this case.
#
# File ~\anaconda3\Lib\site-packages\transformers\utils\hub.py:322, in cached_file(path_or_repo_id, filename, **kwargs)
#     264 def cached_file(
#     265     path_or_repo_id: Union[str, os.PathLike],
#     266     filename: str,
#     267     **kwargs,
#     268 ) -> Optional[str]:
#     269     """
#     270     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     271
#    (...)
#     320     ```
#     321     """
# --> 322     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     323     file = file[0] if file is not None else file
#     324     return file
#
# File ~\anaconda3\Lib\site-packages\transformers\utils\hub.py:479, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     476 try:
#     477     if len(full_filenames) == 1:
#     478         # This is slightly better for only 1 file
# --> 479         hf_hub_download(
#     480             path_or_repo_id,
#     481             filenames[0],
#     482             subfolder=None if len(subfolder) == 0 else subfolder,
#     483             repo_type=repo_type,
#     484             revision=revision,
#     485             cache_dir=cache_dir,
#     486             user_agent=user_agent,
#     487             force_download=force_download,
#     488             proxies=proxies,
#     489             resume_download=resume_download,
#     490             token=token,
#     491             local_files_only=local_files_only,
#     492         )
#     493     else:
#     494         snapshot_download(
#     495             path_or_repo_id,
#     496             allow_patterns=full_filenames,
#    (...)
#     505             local_files_only=local_files_only,
#     506         )
#
# File ~\anaconda3\Lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:1007, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     987     return _hf_hub_download_to_local_dir(
#     988         # Destination
#     989         local_dir=local_dir,
#    (...)
#    1004         local_files_only=local_files_only,
#    1005     )
#    1006 else:
# -> 1007     return _hf_hub_download_to_cache_dir(
#    1008         # Destination
#    1009         cache_dir=cache_dir,
#    1010         # File info
#    1011         repo_id=repo_id,
#    1012         filename=filename,
#    1013         repo_type=repo_type,
#    1014         revision=revision,
#    1015         # HTTP info
#    1016         endpoint=endpoint,
#    1017         etag_timeout=etag_timeout,
#    1018         headers=hf_headers,
#    1019         proxies=proxies,
#    1020         token=token,
#    1021         # Additional options
#    1022         local_files_only=local_files_only,
#    1023         force_download=force_download,
#    1024     )
#
# File ~\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:1168, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1165 # Local file doesn't exist or etag isn't a match => retrieve file from remote (or cache)
#    1167 with WeakFileLock(lock_path):
# -> 1168     _download_to_tmp_and_move(
#    1169         incomplete_path=Path(blob_path + ".incomplete"),
#    1170         destination_path=Path(blob_path),
#    1171         url_to_download=url_to_download,
#    1172         proxies=proxies,
#    1173         headers=headers,
#    1174         expected_size=expected_size,
#    1175         filename=filename,
#    1176         force_download=force_download,
#    1177         etag=etag,
#    1178         xet_file_data=xet_file_data,
#    1179     )
#    1180     if not os.path.exists(pointer_path):
#    1181         _create_symlink(blob_path, pointer_path, new_blob=True)
#
# File ~\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:1735, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download, etag, xet_file_data)
#    1728         if xet_file_data is not None and not constants.HF_HUB_DISABLE_XET:
#    1729             logger.warning(
#    1730                 "Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. "
#    1731                 "Falling back to regular HTTP download. "
#    1732                 "For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`"
#    1733             )
# -> 1735         http_get(
#    1736             url_to_download,
#    1737             f,
#    1738             proxies=proxies,
#    1739             resume_size=resume_size,
#    1740             headers=headers,
#    1741             expected_size=expected_size,
#    1742         )
#    1744 logger.info(f"Download complete. Moving file to {destination_path}")
#    1745 _chmod_and_move(incomplete_path, destination_path)
#
# File ~\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:493, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     491 new_resume_size = resume_size
#     492 try:
# --> 493     for chunk in r.iter_content(chunk_size=constants.DOWNLOAD_CHUNK_SIZE):
#     494         if chunk:  # filter out keep-alive new chunks
#     495             progress.update(len(chunk))
#
# File ~\anaconda3\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~\anaconda3\Lib\site-packages\urllib3\response.py:1060, in HTTPResponse.stream(self, amt, decode_content)
#    1058 else:
#    1059     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1060         data = self.read(amt=amt, decode_content=decode_content)
#    1062         if data:
#    1063             yield data
#
# File ~\anaconda3\Lib\site-packages\urllib3\response.py:949, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     946     if len(self._decoded_buffer) >= amt:
#     947         return self._decoded_buffer.get(amt)
# --> 949 data = self._raw_read(amt)
#     951 flush_decoder = amt is None or (amt != 0 and not data)
#     953 if not data and len(self._decoded_buffer) == 0:
#
# File ~\anaconda3\Lib\site-packages\urllib3\response.py:873, in HTTPResponse._raw_read(self, amt, read1)
#     870 fp_closed = getattr(self._fp, "closed", False)
#     872 with self._error_catcher():
# --> 873     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     874     if amt is not None and amt != 0 and not data:
#     875         # Platform-specific: Buggy versions of Python.
#     876         # Close the connection when no data is returned
#    (...)
#     881         # not properly close the connection in all cases. There is
#     882         # no harm in redundantly calling close.
#     883         self._fp.close()
#
# File ~\anaconda3\Lib\site-packages\urllib3\response.py:856, in HTTPResponse._fp_read(self, amt, read1)
#     853     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     854 else:
#     855     # StringIO doesn't like amt=None
# --> 856     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~\anaconda3\Lib\http\client.py:479, in HTTPResponse.read(self, amt)
#     476 if self.length is not None and amt > self.length:
#     477     # clip the read to the "end of response"
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#     483     self._close_conn()
#
# File ~\anaconda3\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File ~\anaconda3\Lib\ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\Lib\ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
Settings.embed_model = embed_model

Settings.llm = llm

# %%
input_dir_path = './paul_graham'

loader = SimpleDirectoryReader(
            input_dir = input_dir_path,
            required_exts=[".txt"],
            recursive=True
        )
docs = loader.load_data()

# %%
client = qdrant_client.QdrantClient(host="localhost", port=6333)

vector_store = QdrantVectorStore(client=client,
                                 collection_name="document_chat")

storage_context = StorageContext.from_defaults(vector_store=vector_store)

index = VectorStoreIndex.from_documents(docs,
                                        storage_context=storage_context)
